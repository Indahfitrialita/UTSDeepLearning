# %% [markdown]
# **UTS DEEP LEARNING**
#
# Nama : Indah Fitrialita
#
# NPM  : 2206130744

# %% [markdown]
# USING DATASET BUS FROM ULTRALYTICS

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 9.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 191MB/s]

# %%
# Train the model using the 'coco128.yaml' dataset for 3 epochs
results = model.train(data='coco128.yaml', epochs=3)
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# Evaluate the model's performance on the validation set
results = model.val()
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:34<00:00,  4.29s/it]
#                    all        128        929      0.676      0.536      0.623      0.466
#                 person        128        254      0.841      0.646      0.774      0.554
#                bicycle        128          6       0.62      0.333      0.322      0.266
#                    car        128         46      0.837      0.217      0.277      0.176
#             motorcycle        128          5      0.832       0.99      0.962       0.78
#               airplane        128          6      0.818      0.757      0.887      0.663
# ...

# %%
# Perform object detection on an image using the model
results = model('https://ultralytics.com/images/bus.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 246.9ms
# Speed: 5.9ms preprocess, 246.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)

# %%
# Run inference on 'bus.jpg' with arguments
model.predict('bus.jpg', save=True, imgsz=320, conf=0.5)
# Out:
# image 1/1 /content/bus.jpg: 320x256 3 persons, 1 bus, 82.0ms
# Speed: 1.7ms preprocess, 82.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to runs/detect/train3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
Image(filename=f'/content/runs/detect/train3/bus.jpg',width=600)

# %%
# Export the model to ONNX format
success = model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 112.4 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 13.6s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 14.8s, saved as 'runs/detect/train/weights/best.onnx' (12.2 MB)
#
# Export complete (17.1s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# ...

# %% [markdown]
# ***Using Mask Detector Dataset***

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="OsCcKINaerJFouiXJTcl")
project = rf.workspace("joseph-nelson").project("mask-wearing")
dataset = project.version(19).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.205, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Mask-Wearing-19 in yolov8:: 100%|██████████| 3880/3880 [00:01<00:00, 3004.60it/s]

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Train the model using the 'coco128.yaml' dataset for 3 epochs
results = model.train(data='/content/Mask-Wearing-19/data.yaml', epochs=3)
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.predict('/content/Mask-Wearing-19/masker.jpeg', save=True, imgsz=320, conf=0.5)
# Out:
# image 1/1 /content/Mask-Wearing-19/masker.jpeg: 224x320 4 masks, 94.3ms
# Speed: 1.4ms preprocess, 94.3ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to runs/detect/train32
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'mask', 1: 'no-mask'}
#  orig_img: array([[[ 94, 100,  95],
#          [ 94, 100,  95],
#          [ 95, 101,  96],
#          ...,
#          [ 84,  88,  83],
#          [157, 161, 156],
#          [228, 233, 231]],
#
#         [[ 96, 102,  97],
#          [ 96, 102,  97],
#          [ 96, 102,  97],
#          ...,
#          [ 83,  87,  82],
#          [156, 160, 155],
#          [227, 232, 230]],
#
#         [[ 98, 104,  99],
#          [ 98, 104,  99],
#          [ 99, 105, 100],
#          ...,
#          [ 81,  85,  80],
#          [153, 157, 152],
#          [226, 231, 229]],
#
#         ...,
#
# ...

# %%
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
Image(filename=f'/content/runs/detect/train32/masker.jpeg',width=600)

# %%
model.predict('/content/Mask-Wearing-19/mask.jpg', save=True, imgsz=320, conf=0.5)
# Out:
# image 1/1 /content/Mask-Wearing-19/mask.jpg: 320x256 1 mask, 98.6ms
# Speed: 1.8ms preprocess, 98.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 256)
# Results saved to runs/detect/train34
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'mask', 1: 'no-mask'}
#  orig_img: array([[[ 61,  55,  60],
#          [ 60,  54,  59],
#          [ 62,  56,  61],
#          ...,
#          [165, 156, 146],
#          [167, 158, 148],
#          [169, 160, 150]],
#
#         [[ 65,  58,  63],
#          [ 60,  54,  59],
#          [ 59,  53,  58],
#          ...,
#          [165, 156, 146],
#          [167, 158, 148],
#          [169, 160, 150]],
#
#         [[ 75,  65,  71],
#          [ 67,  60,  65],
#          [ 59,  52,  57],
#          ...,
#          [165, 156, 146],
#          [167, 158, 148],
#          [169, 160, 150]],
#
#         ...,
#
# ...

# %%
Image(filename=f'/content/runs/detect/train34/mask.jpg',width=300)
